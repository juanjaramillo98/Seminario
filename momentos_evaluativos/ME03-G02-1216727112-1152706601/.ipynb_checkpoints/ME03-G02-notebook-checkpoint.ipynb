# %% [markdown]
# # Dataset
#
# https://www.datos.gov.co/Educaci-n/Saber-11-2019-2/ynam-yc42/about_data
#
# Resultados anonimizados de las pruebas de Saber 11 del segundo semestre del año 2019-2

# %% [markdown]
# # objetivo
#
# prediccion de los resultados de las pruebas a partir de los datos del estudiente y su familia
#
# Se pretende usar modelos de tipro regresion

# %% [markdown]
# # Importación de librerias

# %%
import pandas as pd

# %% [markdown]
# # Carga del dataset

# %%
df = pd.read_csv("data/Saber_11__2019-2_20240510.csv", low_memory=False)
df.head(5)
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                 TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                 TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                 TI          COLOMBIA           M  02/05/2002 12:00:00 AM
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2    20194  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3    20194  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
# 4    20194  SB11201940280831      ESTUDIANTE              No         COLOMBIA
#
#   ESTU_ETNIA  ... PUNT_INGLES PERCENTIL_INGLES DESEMP_INGLES PUNT_GLOBAL  \
# 0          -  ...        54.0               67            A1         208
# 1          -  ...        63.0               88            A2         299
# 2          -  ...        64.0               89            A2         299
# 3    Ninguno  ...        53.0               67            A1         309
# 4          -  ...        52.0               63            A1         288
#
#   PERCENTIL_GLOBAL ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL  \
# 0               25     50.9421557404314                   2
# 1               83      59.767864431576                   3
# 2               84     50.7642383644749                   2
# 3               88     45.7791353123516                   2
# 4               78     52.9109464277177                   3
#
#   ESTU_NSE_ESTABLECIMIENTO ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# 0                      2.0                 PUBLICAR                        NO
# 1                      4.0                 PUBLICAR                        NO
# 2                      3.0                 PUBLICAR  GENERACION E - GRATUIDAD
# 3                      3.0                 PUBLICAR  GENERACION E - GRATUIDAD
# 4                      3.0                 PUBLICAR                        NO
#
# [5 rows x 82 columns]

# %% [markdown]
# # Variables Globales

# %% [markdown]
# Empezamos con la definicion de una lista de columnas que luego usaremos para eliminar las columnas Inecesarias y ademas definimos una lista de columnas que por las cuales deberemos filtrar para evitar posibles valores atipicos

# %%
# agregamos a la lista las columnas de resultados menos la columna que usaremos como variable dependiente (resultado matematicas)
drop_cols =[
    "PUNT_LECTURA_CRITICA",
    "PERCENTIL_LECTURA_CRITICA",
    "DESEMP_LECTURA_CRITICA",
    "PERCENTIL_MATEMATICAS",
    "DESEMP_MATEMATICAS",
    "PUNT_C_NATURALES",
    "PERCENTIL_C_NATURALES",
    "DESEMP_C_NATURALES",
    "PUNT_SOCIALES_CIUDADANAS",
    "PERCENTIL_SOCIALES_CIUDADANAS",
    "DESEMP_SOCIALES_CIUDADANAS",
    "PUNT_INGLES",
    "PERCENTIL_INGLES",
    "DESEMP_INGLES",
    "PUNT_GLOBAL",
    "PERCENTIL_GLOBAL"
]

# Arreglo con los filtros que se deben aplicar para eliminar datos atipicos
filters = {}

# %% [markdown]
# # Análisis de Columnas

# %% [markdown]
# ## Columnas de texto

# %%
# listamos todas las columnas de texto
text_cols = df.select_dtypes(include = ["object", 'category']).columns.tolist()
estu_text_cols = list(filter(lambda x: 'ESTU' in x, text_cols )) # Columnas con información del estudiante
fami_text_Cols = list(filter(lambda x: 'FAMI' in x, text_cols )) # Columnas con información de la familia del estudiante
cole_text_Cols = list(filter(lambda x: 'COLE' in x, text_cols )) # Columnas con información del colegio del estudiante

# %% [markdown]
# ### Analizar columnas de texto de Estu

# %%
estu_text_cols
# Out:
# ['ESTU_TIPODOCUMENTO',
#  'ESTU_NACIONALIDAD',
#  'ESTU_GENERO',
#  'ESTU_FECHANACIMIENTO',
#  'ESTU_CONSECUTIVO',
#  'ESTU_ESTUDIANTE',
#  'ESTU_TIENEETNIA',
#  'ESTU_PAIS_RESIDE',
#  'ESTU_ETNIA',
#  'ESTU_DEPTO_RESIDE',
#  'ESTU_COD_RESIDE_DEPTO',
#  'ESTU_MCPIO_RESIDE',
#  'ESTU_COD_RESIDE_MCPIO',
#  'ESTU_DEDICACIONLECTURADIARIA',
#  'ESTU_DEDICACIONINTERNET',
#  'ESTU_HORASSEMANATRABAJA',
#  'ESTU_TIPOREMUNERACION',
#  'ESTU_PRIVADO_LIBERTAD',
#  'ESTU_MCPIO_PRESENTACION',
#  'ESTU_DEPTO_PRESENTACION',
#  'ESTU_INSE_INDIVIDUAL',
#  'ESTU_NSE_INDIVIDUAL',
#  'ESTU_ESTADOINVESTIGACION',
#  'ESTU_GENERACION-E']

# %%
df[estu_text_cols].head()
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                 TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                 TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                 TI          COLOMBIA           M  02/05/2002 12:00:00 AM
#
#    ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
# 4  SB11201940280831      ESTUDIANTE              No         COLOMBIA
#
#   ESTU_ETNIA ESTU_DEPTO_RESIDE  ... ESTU_DEDICACIONINTERNET  \
# 0          -         MAGDALENA  ...   Entre 30 y 60 minutos
# 1          -            BOGOTÁ  ...   Entre 30 y 60 minutos
# 2          -           BOLIVAR  ...          Más de 3 horas
# 3    Ninguno            BOGOTÁ  ...   Entre 30 y 60 minutos
# 4          -            BOGOTÁ  ...          Más de 3 horas
#
#   ESTU_HORASSEMANATRABAJA ESTU_TIPOREMUNERACION ESTU_PRIVADO_LIBERTAD  \
# 0       Menos de 10 horas       Si, en efectivo                     N
# 1       Menos de 10 horas       Si, en efectivo                     N
# 2                       0       Si, en efectivo                     N
# 3         Más de 30 horas       Si, en efectivo                     N
# 4         Más de 30 horas                    No                     N
#
#   ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION ESTU_INSE_INDIVIDUAL  \
# 0               SANTA ANA               MAGDALENA     50.9421557404314
# 1             BOGOTÁ D.C.                  BOGOTÁ      59.767864431576
# 2     CARTAGENA DE INDIAS                 BOLIVAR     50.7642383644749
# 3             BOGOTÁ D.C.                  BOGOTÁ     45.7791353123516
# 4             BOGOTÁ D.C.                  BOGOTÁ     52.9109464277177
#
#   ESTU_NSE_INDIVIDUAL ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# 0                   2                 PUBLICAR                        NO
# 1                   3                 PUBLICAR                        NO
# 2                   2                 PUBLICAR  GENERACION E - GRATUIDAD
# 3                   2                 PUBLICAR  GENERACION E - GRATUIDAD
# 4                   3                 PUBLICAR                        NO
#
# [5 rows x 24 columns]

# %%
df[estu_text_cols].describe()
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# count              546212            546212      546212
# unique                 10                33           3
# top                    TI          COLOMBIA           F
# freq               445780            544918      295994
#
#           ESTU_FECHANACIMIENTO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# count                   546212            546212          546212
# unique                   11663            546212               1
# top     01/01/1900 12:00:00 AM  SB11201940031558      ESTUDIANTE
# freq                      1826                 1          546212
#
#        ESTU_TIENEETNIA ESTU_PAIS_RESIDE ESTU_ETNIA ESTU_DEPTO_RESIDE  ...  \
# count           546212           546212     546212            545835  ...
# unique               3               33         21                34  ...
# top                 No         COLOMBIA          -            BOGOTÁ  ...
# freq            506074           544918     506203             83600  ...
#
#        ESTU_DEDICACIONINTERNET ESTU_HORASSEMANATRABAJA ESTU_TIPOREMUNERACION  \
# count                   515914                  545831                530704
# unique                       6                       6                     5
# top          Entre 1 y 3 horas                       0                    No
# freq                    157557                  354503                377436
#
#        ESTU_PRIVADO_LIBERTAD ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# count                 546212                  546212                  546212
# unique                     2                     472                      33
# top                        N             BOGOTÁ D.C.                  BOGOTÁ
# freq                  546086                   84122                   84122
#
#        ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL ESTU_ESTADOINVESTIGACION  \
# count                546208              529171                   546212
# unique               469865                   5                        3
# top                       -                   2                 PUBLICAR
# freq                  17041              197566                   545755
#
#                ESTU_GENERACION-E
# count                     546212
# unique                         4
# top     GENERACION E - GRATUIDAD
# freq                      297357
#
# [4 rows x 24 columns]

# %%
df["ESTU_NSE_INDIVIDUAL"].unique()
# Out:
# array(['2', '3', '4', nan, '1', '-'], dtype=object)

# %%
df["ESTU_ESTADOINVESTIGACION"].unique()
# Out:
# array(['PUBLICAR', 'NO SE COMPROBO IDENTIDAD DEL EXAMINADO',
#        'VALIDEZ OFICINA JURÍDICA'], dtype=object)

# %%
df["ESTU_GENERACION-E"].unique()
# Out:
# array(['NO', 'GENERACION E - GRATUIDAD',
#        'GENERACION E - EXCELENCIA NACIONAL',
#        'GENERACION E - EXCELENCIA DEPARTAMENTAL'], dtype=object)

# %%
drop_cols += [
    "ESTU_TIPODOCUMENTO", #No relevante para el objetivo
    "ESTU_NACIONALIDAD", # filtra por esta columna pendiente
    "ESTU_FECHANACIMIENTO",#No relevante para el objetivo
    "ESTU_CONSECUTIVO", #No relevante para el objetivo, valores unicos
    "ESTU_ESTUDIANTE", #Todas las filas iguales
    "ESTU_TIENEETNIA", #No relevante para el objetivo
    "ESTU_ETNIA", # filtrar por esta columna
    "ESTU_DEPTO_RESIDE", #Nos queamos con la columna del codigo del DEPTO
    "ESTU_MCPIO_RESIDE", #Nos queamos con la columna del codigo del MCPIO
    "ESTU_PRIVADO_LIBERTAD", #filtrar por esta columna 
    "ESTU_NSE_INDIVIDUAL", #No relevante para el objetivo
    "ESTU_ESTADOINVESTIGACION", #debemos filtrar por esta columna 
    "ESTU_GENERACION-E" #No relevante para el objetivo
]

filters.update(
    {
        "ESTU_NACIONALIDAD": "COLOMBIA",
        "ESTU_TIENEETNIA": "No",
        "ESTU_PRIVADO_LIBERTAD": "N"
    }
)

# %% [markdown]
# ### Analizar columnas de texto de Fami

# %%
fami_text_Cols
# Out:
# ['FAMI_ESTRATOVIVIENDA',
#  'FAMI_PERSONASHOGAR',
#  'FAMI_CUARTOSHOGAR',
#  'FAMI_EDUCACIONPADRE',
#  'FAMI_EDUCACIONMADRE',
#  'FAMI_TRABAJOLABORPADRE',
#  'FAMI_TRABAJOLABORMADRE',
#  'FAMI_TIENEINTERNET',
#  'FAMI_TIENESERVICIOTV',
#  'FAMI_TIENECOMPUTADOR',
#  'FAMI_TIENELAVADORA',
#  'FAMI_TIENEHORNOMICROOGAS',
#  'FAMI_TIENEAUTOMOVIL',
#  'FAMI_TIENEMOTOCICLETA',
#  'FAMI_TIENECONSOLAVIDEOJUEGOS',
#  'FAMI_NUMLIBROS',
#  'FAMI_COMELECHEDERIVADOS',
#  'FAMI_COMECARNEPESCADOHUEVO',
#  'FAMI_COMECEREALFRUTOSLEGUMBRE',
#  'FAMI_SITUACIONECONOMICA']

# %%
df[fami_text_Cols].head()
# Out:
#   FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR FAMI_CUARTOSHOGAR  \
# 0            Estrato 3              5 a 6             Cinco
# 1            Estrato 3            9 o más              Tres
# 2            Estrato 1              5 a 6               Dos
# 3            Estrato 3              3 a 4               Dos
# 4            Estrato 3              3 a 4            Cuatro
#
#                   FAMI_EDUCACIONPADRE                   FAMI_EDUCACIONMADRE  \
# 0      Educación profesional completa    Secundaria (Bachillerato) completa
# 1      Técnica o tecnológica completa        Técnica o tecnológica completa
# 2  Secundaria (Bachillerato) completa    Secundaria (Bachillerato) completa
# 3                 Primaria incompleta    Secundaria (Bachillerato) completa
# 4  Secundaria (Bachillerato) completa  Secundaria (Bachillerato) incompleta
#
#                               FAMI_TRABAJOLABORPADRE  \
# 0                                          No aplica
# 1  Trabaja por cuenta propia (por ejemplo plomero...
# 2       Es vendedor o trabaja en atención al público
# 3                                          No aplica
# 4          Trabaja en el hogar, no trabaja o estudia
#
#                               FAMI_TRABAJOLABORMADRE FAMI_TIENEINTERNET  \
# 0          Trabaja en el hogar, no trabaja o estudia                 Si
# 1  Es dueño de un negocio pequeño (tiene pocos em...                 Si
# 2       Es vendedor o trabaja en atención al público                 No
# 3  Es dueño de un negocio pequeño (tiene pocos em...                 No
# 4          Trabaja en el hogar, no trabaja o estudia                 Si
#
#   FAMI_TIENESERVICIOTV FAMI_TIENECOMPUTADOR FAMI_TIENELAVADORA  \
# 0                   Si                   No                 Si
# 1                   Si                   Si                 Si
# 2                   Si                   No                 Si
# 3                   No                   Si                 No
# 4                   Si                   Si                 Si
#
#   FAMI_TIENEHORNOMICROOGAS FAMI_TIENEAUTOMOVIL FAMI_TIENEMOTOCICLETA  \
# 0                       Si                  No                    No
# 1                       Si                  Si                    No
# 2                       No                  No                    No
# 3                       No                  No                    No
# 4                       Si                  No                    No
#
#   FAMI_TIENECONSOLAVIDEOJUEGOS     FAMI_NUMLIBROS  \
# 0                           No  MÁS DE 100 LIBROS
# 1                           No  MÁS DE 100 LIBROS
# 2                           No    26 A 100 LIBROS
# 3                           No     11 A 25 LIBROS
# 4                           No    26 A 100 LIBROS
#
#        FAMI_COMELECHEDERIVADOS    FAMI_COMECARNEPESCADOHUEVO  \
# 0       1 o 2 veces por semana        3 a 5 veces por semana
# 1  Todos o casi todos los días        3 a 5 veces por semana
# 2  Todos o casi todos los días   Todos o casi todos los días
# 3  Todos o casi todos los días   Todos o casi todos los días
# 4  Todos o casi todos los días  Nunca o rara vez comemos eso
#
#   FAMI_COMECEREALFRUTOSLEGUMBRE FAMI_SITUACIONECONOMICA
# 0  Nunca o rara vez comemos eso                    Peor
# 1        1 o 2 veces por semana                   Mejor
# 2        3 a 5 veces por semana                   Igual
# 3        3 a 5 veces por semana                   Igual
# 4   Todos o casi todos los días                   Mejor

# %%
df[fami_text_Cols].describe()
# Out:
#        FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR FAMI_CUARTOSHOGAR  \
# count                546186             537749            539794
# unique                    8                  6                 7
# top               Estrato 2              3 a 4              Tres
# freq                 188314             257604            207232
#
#                        FAMI_EDUCACIONPADRE  \
# count                               537920
# unique                                  13
# top     Secundaria (Bachillerato) completa
# freq                                117488
#
#                        FAMI_EDUCACIONMADRE  \
# count                               525253
# unique                                  13
# top     Secundaria (Bachillerato) completa
# freq                                136286
#
#                      FAMI_TRABAJOLABORPADRE  \
# count                                538081
# unique                                   14
# top     Es agricultor, pesquero o jornalero
# freq                                  78187
#
#                            FAMI_TRABAJOLABORMADRE FAMI_TIENEINTERNET  \
# count                                      538743             537875
# unique                                         14                  3
# top     Trabaja en el hogar, no trabaja o estudia                 Si
# freq                                       213377             314042
#
#        FAMI_TIENESERVICIOTV FAMI_TIENECOMPUTADOR FAMI_TIENELAVADORA  \
# count                523932               538027             538569
# unique                    3                    3                  3
# top                      Si                   Si                 Si
# freq                 391419               295409             405542
#
#        FAMI_TIENEHORNOMICROOGAS FAMI_TIENEAUTOMOVIL FAMI_TIENEMOTOCICLETA  \
# count                    537582              538006                537395
# unique                        3                   3                     3
# top                          No                  No                    No
# freq                     280967              401388                308054
#
#        FAMI_TIENECONSOLAVIDEOJUEGOS FAMI_NUMLIBROS FAMI_COMELECHEDERIVADOS  \
# count                        538487         537558                  523907
# unique                            3              5                       5
# top                              No  0 A 10 LIBROS  1 o 2 veces por semana
# freq                         410475         207526                  170538
#
#          FAMI_COMECARNEPESCADOHUEVO FAMI_COMECEREALFRUTOSLEGUMBRE  \
# count                        536587                        523880
# unique                            5                             5
# top     Todos o casi todos los días        1 o 2 veces por semana
# freq                         209228                        198491
#
#        FAMI_SITUACIONECONOMICA
# count                   537953
# unique                       4
# top                      Igual
# freq                    322524

# %%
df["FAMI_SITUACIONECONOMICA"].unique()
# Out:
# array(['Peor', 'Mejor', 'Igual', '-', nan], dtype=object)

# %%
drop_cols+=[
    "FAMI_CUARTOSHOGAR", #No relevante para el objetivo
    "FAMI_TIENELAVADORA" #No relevante para el objetivo
    "FAMI_TIENEHORNOMICROOGAS", #No relevante para el objetivo
    "FAMI_TIENEAUTOMOVIL", #No relevante para el objetivo
    "FAMI_TIENEMOTOCICLETA", #No relevante para el objetivo
    "FAMI_TIENECONSOLAVIDEOJUEGOS" #No relevante para el objetivo
]

# %% [markdown]
# ### Analizar columnas de texto de Cole

# %%
df[cole_text_Cols].head()
# Out:
#                          COLE_NOMBRE_ESTABLECIMIENTO COLE_GENERO  \
# 0  INSTITUCION EDUCATIVA DEPARTAMENTAL ANTONIO BR...       MIXTO
# 1                                    GIMN SAN ANGELO       MIXTO
# 2  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.       MIXTO
# 3         COLEGIO VIRGINIA GUTIERREZ DE PINEDA (IED)       MIXTO
# 4                      COLEGIO PALERMO  IEDIP  (IED)       MIXTO
#
#   COLE_NATURALEZA COLE_CALENDARIO COLE_BILINGUE      COLE_CARACTER  \
# 0         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 1      NO OFICIAL               A             -          ACADÉMICO
# 2         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 3         OFICIAL               A             -          ACADÉMICO
# 4         OFICIAL               A             N  TÉCNICO/ACADÉMICO
#
#                                     COLE_NOMBRE_SEDE COLE_SEDE_PRINCIPAL  \
# 0                   COL DPTAL ANTONIO BRUGES CARMONA                   S
# 1                                    GIMN SAN ANGELO                   S
# 2  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.                   S
# 3   COL VIRGINIA GUTIERREZ DE PINEDA (INS EDUC DIST)                   S
# 4                       CENT EDUC DIST PALERMO CEDIP                   S
#
#   COLE_AREA_UBICACION COLE_JORNADA COLE_MCPIO_UBICACION COLE_DEPTO_UBICACION
# 0              URBANO       MAÑANA            SANTA ANA            MAGDALENA
# 1              URBANO     COMPLETA          BOGOTÁ D.C.               BOGOTÁ
# 2              URBANO       MAÑANA  CARTAGENA DE INDIAS              BOLIVAR
# 3              URBANO       MAÑANA          BOGOTÁ D.C.               BOGOTÁ
# 4              URBANO       MAÑANA          BOGOTÁ D.C.               BOGOTÁ

# %%
df[cole_text_Cols].describe()
# Out:
#                            COLE_NOMBRE_ESTABLECIMIENTO COLE_GENERO  \
# count                                           546212      546212
# unique                                            9372           3
# top     INSTITUCION EDUCATIVA FRANCISCO JOSE DE CALDAS       MIXTO
# freq                                              1147      528780
#
#        COLE_NATURALEZA COLE_CALENDARIO COLE_BILINGUE COLE_CARACTER  \
# count           546212          546212        546212        532464
# unique               2               3             3             5
# top            OFICIAL               A             N     ACADÉMICO
# freq            416011          541901        453280        284200
#
#                     COLE_NOMBRE_SEDE COLE_SEDE_PRINCIPAL COLE_AREA_UBICACION  \
# count                         546212              546212              546212
# unique                         10284                   2                   2
# top     INSTITUTO TECNICO INDUSTRIAL                   S              URBANO
# freq                             881              523322              460467
#
#        COLE_JORNADA COLE_MCPIO_UBICACION COLE_DEPTO_UBICACION
# count        546212               546212               546212
# unique            6                 1030                   33
# top          MAÑANA          BOGOTÁ D.C.               BOGOTÁ
# freq         257060                82832                82832

# %%
df["COLE_NATURALEZA"].unique()
# Out:
# array(['OFICIAL', 'NO OFICIAL'], dtype=object)

# %%
df["COLE_CARACTER"].unique()
# Out:
# array(['TÉCNICO/ACADÉMICO', 'ACADÉMICO', nan, 'TÉCNICO', 'NO APLICA', '-'],
#       dtype=object)

# %%
df["COLE_JORNADA"].unique()
# Out:
# array(['MAÑANA', 'COMPLETA', 'NOCHE', 'UNICA', 'TARDE', 'SABATINA'],
#       dtype=object)

# %%
drop_cols+=[
    "COLE_NOMBRE_ESTABLECIMIENTO", #valores unicos
    "COLE_GENERO", #filtrar por mixto categoria dominante
    "COLE_NATURALEZA",
    "COLE_CALENDARIO", #filtramos A
    "COLE_BILINGUE", #No relevante para el objetivo
    "COLE_CARACTER",#No relevante para el objetivo
    "COLE_NOMBRE_SEDE",#No relevante para el objetivo valores unicos}
    "COLE_SEDE_PRINCIPAL",#No relevante para el objetivo 
    "COLE_MCPIO_UBICACION",#No relevante para el objetivo ya tango esta info del estudiante
    "COLE_DEPTO_UBICACION" #No relevante para el objetivo ya tango esta info del estudiante
]

filters.update(
    {
        "COLE_GENERO": "MIXTO",
        "COLE_CALENDARIO": "A"
    }
)

# %% [markdown]
# ## Columnas Numericas

# %%
# listamos todas las columnas de numeros
numCols=df.select_dtypes(include = ['float64','int32','int64']).columns.tolist()
estu_num_cols = list(filter(lambda x: 'ESTU' in x, numCols ))
fami_num_Cols = list(filter(lambda x: 'COLE' in x, numCols ))

# %% [markdown]
# ### Analizar columnas de textonumericas de Estu

# %%
estu_num_cols
# Out:
# ['ESTU_COD_MCPIO_PRESENTACION',
#  'ESTU_COD_DEPTO_PRESENTACION',
#  'ESTU_NSE_ESTABLECIMIENTO']

# %%
df[estu_num_cols].head()
# Out:
#    ESTU_COD_MCPIO_PRESENTACION  ESTU_COD_DEPTO_PRESENTACION  \
# 0                        47707                           47
# 1                        11001                           11
# 2                        13001                           13
# 3                        11001                           11
# 4                        11001                           11
#
#    ESTU_NSE_ESTABLECIMIENTO
# 0                       2.0
# 1                       4.0
# 2                       3.0
# 3                       3.0
# 4                       3.0

# %%
drop_cols += estu_num_cols #ninguna coluna numerica del Estu es prescindible

# %% [markdown]
# # Filtrado de filas

# %%
def filtrar(df, filtros):
    """
    Función para filtrar filas de un dataframe de pandas
    """
    query = ""
    filtered_df = df
    for key in filtros:
        filtered_df = filtered_df[filtered_df[key] == filtros[key]]
        
    return filtered_df

# %%
filtrar(df, filters)
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                      TI          COLOMBIA           M
# 1                      TI          COLOMBIA           M
# 2                      TI          COLOMBIA           M
# 4                      TI          COLOMBIA           M
# 5                      CC          COLOMBIA           M
# ...                   ...               ...         ...
# 546207                 CC          COLOMBIA           M
# 546208                 TI          COLOMBIA           M
# 546209                 TI          COLOMBIA           M
# 546210                 TI          COLOMBIA           M
# 546211                 TI          COLOMBIA           M
#
#           ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 0       02/18/2002 12:00:00 AM    20194  SB11201940031558      ESTUDIANTE
# 1       06/28/2003 12:00:00 AM    20194  SB11201940303339      ESTUDIANTE
# 2       06/02/2001 12:00:00 AM    20194  SB11201940255017      ESTUDIANTE
# 4       02/05/2002 12:00:00 AM    20194  SB11201940280831      ESTUDIANTE
# 5       04/08/1999 12:00:00 AM    20194  SB11201940212273      ESTUDIANTE
# ...                        ...      ...               ...             ...
# 546207  02/25/1999 12:00:00 AM    20194  SB11201940195862      ESTUDIANTE
# 546208  10/14/2002 12:00:00 AM    20194  SB11201940253002      ESTUDIANTE
# 546209  11/22/2002 12:00:00 AM    20194  SB11201940364767      ESTUDIANTE
# 546210  11/10/2002 12:00:00 AM    20194  SB11201940210026      ESTUDIANTE
# 546211  06/02/2002 12:00:00 AM    20194  SB11201940074679      ESTUDIANTE
#
#        ESTU_TIENEETNIA ESTU_PAIS_RESIDE ESTU_ETNIA  ... PUNT_INGLES  \
# 0                   No         COLOMBIA          -  ...        54.0
# 1                   No         COLOMBIA          -  ...        63.0
# 2                   No         COLOMBIA          -  ...        64.0
# 4                   No         COLOMBIA          -  ...        52.0
# 5                   No         COLOMBIA          -  ...        35.0
# ...                ...              ...        ...  ...         ...
# 546207              No         COLOMBIA          -  ...        58.0
# 546208              No         COLOMBIA          -  ...        74.0
# 546209              No         COLOMBIA          -  ...        72.0
# 546210              No         COLOMBIA          -  ...        46.0
# 546211              No         COLOMBIA          -  ...        74.0
#
#        PERCENTIL_INGLES DESEMP_INGLES PUNT_GLOBAL PERCENTIL_GLOBAL  \
# 0                    67            A1         208               25
# 1                    88            A2         299               83
# 2                    89            A2         299               84
# 4                    63            A1         288               78
# 5                    14            A-         198               19
# ...                 ...           ...         ...              ...
# 546207               79            A2         360               99
# 546208               97            B1         360               99
# 546209               96            B1         377              100
# 546210               45            A-         278               73
# 546211               97            B1         365               99
#
#        ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL ESTU_NSE_ESTABLECIMIENTO  \
# 0          50.9421557404314                   2                      2.0
# 1           59.767864431576                   3                      4.0
# 2          50.7642383644749                   2                      3.0
# 4          52.9109464277177                   3                      3.0
# 5          45.0066313321494                   2                      2.0
# ...                     ...                 ...                      ...
# 546207     47.5807720132296                   2                      2.0
# 546208      57.406418472062                   3                      4.0
# 546209     71.2254308010465                   4                      3.0
# 546210     38.1334451267846                   1                      2.0
# 546211     49.7833058735661                   2                      3.0
#
#        ESTU_ESTADOINVESTIGACION                        ESTU_GENERACION-E
# 0                      PUBLICAR                                       NO
# 1                      PUBLICAR                                       NO
# 2                      PUBLICAR                 GENERACION E - GRATUIDAD
# 4                      PUBLICAR                                       NO
# 5                      PUBLICAR                 GENERACION E - GRATUIDAD
# ...                         ...                                      ...
# 546207                 PUBLICAR       GENERACION E - EXCELENCIA NACIONAL
# 546208                 PUBLICAR       GENERACION E - EXCELENCIA NACIONAL
# 546209                 PUBLICAR  GENERACION E - EXCELENCIA DEPARTAMENTAL
# 546210                 PUBLICAR                 GENERACION E - GRATUIDAD
# 546211                 PUBLICAR       GENERACION E - EXCELENCIA NACIONAL
#
# [484058 rows x 82 columns]
