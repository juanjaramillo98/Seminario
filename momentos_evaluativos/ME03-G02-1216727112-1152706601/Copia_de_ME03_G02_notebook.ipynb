# %% [markdown]
# <a href="https://colab.research.google.com/github/juanjaramillo98/Seminario/blob/entregable_3/momentos_evaluativos/ME03-G02-1216727112-1152706601/Copia_de_ME03_G02_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Cargar datos con colab
## =============================================================================

from google.colab import drive
import os

drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
os.chdir("/gdrive/MyDrive/seminario")
# !ls
# Out:
# Saber_11__2019-2_20240510.csv

# %% [markdown]
# # Dataset
#
# https://www.datos.gov.co/Educaci-n/Saber-11-2019-2/ynam-yc42/about_data
#
# Resultados anonimizados de las pruebas de Saber 11 del segundo semestre del año 2019-2

# %% [markdown]
# # Objetivo
#
# Predecir los resultados de las pruebas a partir de los datos del estudiente y su familia, utilizando modelos de regresión

# %% [markdown]
# # Importación de librerias

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Carga del dataset

# %%
#df = pd.read_csv("data/Saber_11__2019-2_20240510.csv", low_memory=False)
df = pd.read_csv("Saber_11__2019-2_20240510.csv", low_memory=False)
df.head(5)
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                 TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                 TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                 TI          COLOMBIA           M  02/05/2002 12:00:00 AM
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2    20194  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3    20194  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
# 4    20194  SB11201940280831      ESTUDIANTE              No         COLOMBIA
#
#   ESTU_ETNIA ESTU_DEPTO_RESIDE ESTU_COD_RESIDE_DEPTO    ESTU_MCPIO_RESIDE  \
# 0          -         MAGDALENA                    47            SANTA ANA
# 1          -            BOGOTÁ                    11          BOGOTÁ D.C.
# 2          -           BOLIVAR                    13  CARTAGENA DE INDIAS
# 3    Ninguno            BOGOTÁ                    11          BOGOTÁ D.C.
# 4          -            BOGOTÁ                    11          BOGOTÁ D.C.
#
#   ESTU_COD_RESIDE_MCPIO FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR  \
# 0                 47707            Estrato 3              5 a 6
# 1                 11001            Estrato 3            9 o más
# 2                 13001            Estrato 1              5 a 6
# 3                 11001            Estrato 3              3 a 4
# 4                 11001            Estrato 3              3 a 4
#
#   FAMI_CUARTOSHOGAR                 FAMI_EDUCACIONPADRE  \
# 0             Cinco      Educación profesional completa
# 1              Tres      Técnica o tecnológica completa
# 2               Dos  Secundaria (Bachillerato) completa
# 3               Dos                 Primaria incompleta
# 4            Cuatro  Secundaria (Bachillerato) completa
#
#                     FAMI_EDUCACIONMADRE  \
# 0    Secundaria (Bachillerato) completa
# 1        Técnica o tecnológica completa
# 2    Secundaria (Bachillerato) completa
# 3    Secundaria (Bachillerato) completa
# 4  Secundaria (Bachillerato) incompleta
#
#                               FAMI_TRABAJOLABORPADRE  \
# 0                                          No aplica
# 1  Trabaja por cuenta propia (por ejemplo plomero...
# 2       Es vendedor o trabaja en atención al público
# 3                                          No aplica
# 4          Trabaja en el hogar, no trabaja o estudia
#
#                               FAMI_TRABAJOLABORMADRE FAMI_TIENEINTERNET  \
# 0          Trabaja en el hogar, no trabaja o estudia                 Si
# 1  Es dueño de un negocio pequeño (tiene pocos em...                 Si
# 2       Es vendedor o trabaja en atención al público                 No
# 3  Es dueño de un negocio pequeño (tiene pocos em...                 No
# 4          Trabaja en el hogar, no trabaja o estudia                 Si
#
#   FAMI_TIENESERVICIOTV FAMI_TIENECOMPUTADOR FAMI_TIENELAVADORA  \
# 0                   Si                   No                 Si
# 1                   Si                   Si                 Si
# 2                   Si                   No                 Si
# 3                   No                   Si                 No
# 4                   Si                   Si                 Si
#
#   FAMI_TIENEHORNOMICROOGAS FAMI_TIENEAUTOMOVIL FAMI_TIENEMOTOCICLETA  \
# 0                       Si                  No                    No
# 1                       Si                  Si                    No
# 2                       No                  No                    No
# 3                       No                  No                    No
# 4                       Si                  No                    No
#
#   FAMI_TIENECONSOLAVIDEOJUEGOS     FAMI_NUMLIBROS  \
# 0                           No  MÁS DE 100 LIBROS
# 1                           No  MÁS DE 100 LIBROS
# 2                           No    26 A 100 LIBROS
# 3                           No     11 A 25 LIBROS
# 4                           No    26 A 100 LIBROS
#
#        FAMI_COMELECHEDERIVADOS    FAMI_COMECARNEPESCADOHUEVO  \
# 0       1 o 2 veces por semana        3 a 5 veces por semana
# 1  Todos o casi todos los días        3 a 5 veces por semana
# 2  Todos o casi todos los días   Todos o casi todos los días
# 3  Todos o casi todos los días   Todos o casi todos los días
# 4  Todos o casi todos los días  Nunca o rara vez comemos eso
#
#   FAMI_COMECEREALFRUTOSLEGUMBRE FAMI_SITUACIONECONOMICA  \
# 0  Nunca o rara vez comemos eso                    Peor
# 1        1 o 2 veces por semana                   Mejor
# 2        3 a 5 veces por semana                   Igual
# 3        3 a 5 veces por semana                   Igual
# 4   Todos o casi todos los días                   Mejor
#
#   ESTU_DEDICACIONLECTURADIARIA ESTU_DEDICACIONINTERNET  \
# 0        Entre 30 y 60 minutos   Entre 30 y 60 minutos
# 1        Entre 30 y 60 minutos   Entre 30 y 60 minutos
# 2        Entre 30 y 60 minutos          Más de 3 horas
# 3           30 minutos o menos   Entre 30 y 60 minutos
# 4   No leo por entretenimiento          Más de 3 horas
#
#   ESTU_HORASSEMANATRABAJA ESTU_TIPOREMUNERACION  COLE_CODIGO_ICFES  \
# 0       Menos de 10 horas       Si, en efectivo              39008
# 1       Menos de 10 horas       Si, en efectivo             128611
# 2                       0       Si, en efectivo              35493
# 3         Más de 30 horas       Si, en efectivo             138032
# 4         Más de 30 horas                    No             217406
#
#    COLE_COD_DANE_ESTABLECIMIENTO  \
# 0                   147707000156
# 1                   311001105383
# 2                   113001001719
# 3                   111001107069
# 4                   111001094897
#
#                          COLE_NOMBRE_ESTABLECIMIENTO COLE_GENERO  \
# 0  INSTITUCION EDUCATIVA DEPARTAMENTAL ANTONIO BR...       MIXTO
# 1                                    GIMN SAN ANGELO       MIXTO
# 2  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.       MIXTO
# 3         COLEGIO VIRGINIA GUTIERREZ DE PINEDA (IED)       MIXTO
# 4                      COLEGIO PALERMO  IEDIP  (IED)       MIXTO
#
#   COLE_NATURALEZA COLE_CALENDARIO COLE_BILINGUE      COLE_CARACTER  \
# 0         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 1      NO OFICIAL               A             -          ACADÉMICO
# 2         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 3         OFICIAL               A             -          ACADÉMICO
# 4         OFICIAL               A             N  TÉCNICO/ACADÉMICO
#
#    COLE_COD_DANE_SEDE                                   COLE_NOMBRE_SEDE  \
# 0        147707000156                   COL DPTAL ANTONIO BRUGES CARMONA
# 1        311001105383                                    GIMN SAN ANGELO
# 2        113001001719  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.
# 3        111001107069   COL VIRGINIA GUTIERREZ DE PINEDA (INS EDUC DIST)
# 4        111001094897                       CENT EDUC DIST PALERMO CEDIP
#
#   COLE_SEDE_PRINCIPAL COLE_AREA_UBICACION COLE_JORNADA  \
# 0                   S              URBANO       MAÑANA
# 1                   S              URBANO     COMPLETA
# 2                   S              URBANO       MAÑANA
# 3                   S              URBANO       MAÑANA
# 4                   S              URBANO       MAÑANA
#
#    COLE_COD_MCPIO_UBICACION COLE_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION  \
# 0                     47707            SANTA ANA                        47
# 1                     11001          BOGOTÁ D.C.                        11
# 2                     13001  CARTAGENA DE INDIAS                        13
# 3                     11001          BOGOTÁ D.C.                        11
# 4                     11001          BOGOTÁ D.C.                        11
#
#   COLE_DEPTO_UBICACION ESTU_PRIVADO_LIBERTAD  ESTU_COD_MCPIO_PRESENTACION  \
# 0            MAGDALENA                     N                        47707
# 1               BOGOTÁ                     N                        11001
# 2              BOLIVAR                     N                        13001
# 3               BOGOTÁ                     N                        11001
# 4               BOGOTÁ                     N                        11001
#
#   ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 0               SANTA ANA               MAGDALENA
# 1             BOGOTÁ D.C.                  BOGOTÁ
# 2     CARTAGENA DE INDIAS                 BOLIVAR
# 3             BOGOTÁ D.C.                  BOGOTÁ
# 4             BOGOTÁ D.C.                  BOGOTÁ
#
#    ESTU_COD_DEPTO_PRESENTACION  PUNT_LECTURA_CRITICA  \
# 0                           47                    47
# 1                           11                    60
# 2                           13                    66
# 3                           11                    62
# 4                           11                    63
#
#    PERCENTIL_LECTURA_CRITICA  DESEMP_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# 0                         33                       2                48
# 1                         76                       3                65
# 2                         91                       4                57
# 3                         81                       3                54
# 4                         85                       3                57
#
#    PERCENTIL_MATEMATICAS  DESEMP_MATEMATICAS  PUNT_C_NATURALES  \
# 0                     42                   2                37
# 1                     88                   3                54
# 2                     70                   3                41
# 3                     60                   3                61
# 4                     70                   3                55
#
#    PERCENTIL_C_NATURALES  DESEMP_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  \
# 0                     15                   1                        30
# 1                     71                   2                        59
# 2                     29                   2                        74
# 3                     87                   3                        73
# 4                     74                   2                        57
#
#    PERCENTIL_SOCIALES_CIUDADANAS  DESEMP_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# 0                              8                           1         54.0
# 1                             83                           3         63.0
# 2                             99                           4         64.0
# 3                             99                           4         53.0
# 4                             79                           3         52.0
#
#    PERCENTIL_INGLES DESEMP_INGLES  PUNT_GLOBAL PERCENTIL_GLOBAL  \
# 0                67            A1          208               25
# 1                88            A2          299               83
# 2                89            A2          299               84
# 3                67            A1          309               88
# 4                63            A1          288               78
#
#   ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL  ESTU_NSE_ESTABLECIMIENTO  \
# 0     50.9421557404314                   2                       2.0
# 1      59.767864431576                   3                       4.0
# 2     50.7642383644749                   2                       3.0
# 3     45.7791353123516                   2                       3.0
# 4     52.9109464277177                   3                       3.0
#
#   ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# 0                 PUBLICAR                        NO
# 1                 PUBLICAR                        NO
# 2                 PUBLICAR  GENERACION E - GRATUIDAD
# 3                 PUBLICAR  GENERACION E - GRATUIDAD
# 4                 PUBLICAR                        NO

# %% [markdown]
# # Variables Globales

# %% [markdown]
# Empezamos con la definicion de una lista de columnas que luego usaremos para eliminar las columnas Inecesarias y ademas definimos una lista de columnas que por las cuales deberemos filtrar para evitar posibles valores atipicos

# %%
# lista de columnas que se eliminaran
drop_cols =[
]

# Arreglo con los filtros que se deben aplicar para eliminar datos atipicos
filters = {}

# %% [markdown]
# # Análisis de Columnas

# %% [markdown]
# ## Columnas de texto

# %%
# listamos todas las columnas de texto
text_cols = df.select_dtypes(include = ["object", 'category']).columns.tolist()
estu_text_cols = list(filter(lambda x: 'ESTU' in x, text_cols )) # Columnas con información del estudiante
fami_text_Cols = list(filter(lambda x: 'FAMI' in x, text_cols )) # Columnas con información de la familia del estudiante
cole_text_Cols = list(filter(lambda x: 'COLE' in x, text_cols )) # Columnas con información del colegio del estudiante
restante_texto_cols = list(filter(lambda x: not 'ESTU' in x and not 'FAMI' in x and not 'COLE' in x, text_cols))

# %% [markdown]
# ### Analizar columnas de texto de Estu

# %%
estu_text_cols
# Out:
# ['ESTU_TIPODOCUMENTO',
#  'ESTU_NACIONALIDAD',
#  'ESTU_GENERO',
#  'ESTU_FECHANACIMIENTO',
#  'ESTU_CONSECUTIVO',
#  'ESTU_ESTUDIANTE',
#  'ESTU_TIENEETNIA',
#  'ESTU_PAIS_RESIDE',
#  'ESTU_ETNIA',
#  'ESTU_DEPTO_RESIDE',
#  'ESTU_COD_RESIDE_DEPTO',
#  'ESTU_MCPIO_RESIDE',
#  'ESTU_COD_RESIDE_MCPIO',
#  'ESTU_DEDICACIONLECTURADIARIA',
#  'ESTU_DEDICACIONINTERNET',
#  'ESTU_HORASSEMANATRABAJA',
#  'ESTU_TIPOREMUNERACION',
#  'ESTU_PRIVADO_LIBERTAD',
#  'ESTU_MCPIO_PRESENTACION',
#  'ESTU_DEPTO_PRESENTACION',
#  'ESTU_INSE_INDIVIDUAL',
#  'ESTU_NSE_INDIVIDUAL',
#  'ESTU_ESTADOINVESTIGACION',
#  'ESTU_GENERACION-E']

# %%
df[estu_text_cols].head()
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                 TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                 TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                 TI          COLOMBIA           M  02/05/2002 12:00:00 AM
#
#    ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
# 4  SB11201940280831      ESTUDIANTE              No         COLOMBIA
#
#   ESTU_ETNIA ESTU_DEPTO_RESIDE ESTU_COD_RESIDE_DEPTO    ESTU_MCPIO_RESIDE  \
# 0          -         MAGDALENA                    47            SANTA ANA
# 1          -            BOGOTÁ                    11          BOGOTÁ D.C.
# 2          -           BOLIVAR                    13  CARTAGENA DE INDIAS
# 3    Ninguno            BOGOTÁ                    11          BOGOTÁ D.C.
# 4          -            BOGOTÁ                    11          BOGOTÁ D.C.
#
#   ESTU_COD_RESIDE_MCPIO ESTU_DEDICACIONLECTURADIARIA ESTU_DEDICACIONINTERNET  \
# 0                 47707        Entre 30 y 60 minutos   Entre 30 y 60 minutos
# 1                 11001        Entre 30 y 60 minutos   Entre 30 y 60 minutos
# 2                 13001        Entre 30 y 60 minutos          Más de 3 horas
# 3                 11001           30 minutos o menos   Entre 30 y 60 minutos
# 4                 11001   No leo por entretenimiento          Más de 3 horas
#
#   ESTU_HORASSEMANATRABAJA ESTU_TIPOREMUNERACION ESTU_PRIVADO_LIBERTAD  \
# 0       Menos de 10 horas       Si, en efectivo                     N
# 1       Menos de 10 horas       Si, en efectivo                     N
# 2                       0       Si, en efectivo                     N
# 3         Más de 30 horas       Si, en efectivo                     N
# 4         Más de 30 horas                    No                     N
#
#   ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION ESTU_INSE_INDIVIDUAL  \
# 0               SANTA ANA               MAGDALENA     50.9421557404314
# 1             BOGOTÁ D.C.                  BOGOTÁ      59.767864431576
# 2     CARTAGENA DE INDIAS                 BOLIVAR     50.7642383644749
# 3             BOGOTÁ D.C.                  BOGOTÁ     45.7791353123516
# 4             BOGOTÁ D.C.                  BOGOTÁ     52.9109464277177
#
#   ESTU_NSE_INDIVIDUAL ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# 0                   2                 PUBLICAR                        NO
# 1                   3                 PUBLICAR                        NO
# 2                   2                 PUBLICAR  GENERACION E - GRATUIDAD
# 3                   2                 PUBLICAR  GENERACION E - GRATUIDAD
# 4                   3                 PUBLICAR                        NO

# %%
df[estu_text_cols].describe()
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# count              546212            546212      546212
# unique                 10                33           3
# top                    TI          COLOMBIA           F
# freq               445780            544918      295994
#
#           ESTU_FECHANACIMIENTO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# count                   546212            546212          546212
# unique                   11663            546212               1
# top     01/01/1900 12:00:00 AM  SB11201940031558      ESTUDIANTE
# freq                      1826                 1          546212
#
#        ESTU_TIENEETNIA ESTU_PAIS_RESIDE ESTU_ETNIA ESTU_DEPTO_RESIDE  \
# count           546212           546212     546212            545835
# unique               3               33         21                34
# top                 No         COLOMBIA          -            BOGOTÁ
# freq            506074           544918     506203             83600
#
#        ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE ESTU_COD_RESIDE_MCPIO  \
# count                 546212            545835                546212
# unique                    35              1031                  1115
# top                       11       BOGOTÁ D.C.                 11001
# freq                   83600             83600                 83600
#
#        ESTU_DEDICACIONLECTURADIARIA ESTU_DEDICACIONINTERNET  \
# count                        545585                  515914
# unique                            6                       6
# top              30 minutos o menos       Entre 1 y 3 horas
# freq                         199094                  157557
#
#        ESTU_HORASSEMANATRABAJA ESTU_TIPOREMUNERACION ESTU_PRIVADO_LIBERTAD  \
# count                   545831                530704                546212
# unique                       6                     5                     2
# top                          0                    No                     N
# freq                    354503                377436                546086
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION ESTU_INSE_INDIVIDUAL  \
# count                   546212                  546212               546208
# unique                     472                      33               469865
# top                BOGOTÁ D.C.                  BOGOTÁ                    -
# freq                     84122                   84122                17041
#
#        ESTU_NSE_INDIVIDUAL ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# count               529171                   546212                    546212
# unique                   5                        3                         4
# top                      2                 PUBLICAR  GENERACION E - GRATUIDAD
# freq                197566                   545755                    297357

# %%
df["ESTU_NSE_INDIVIDUAL"].unique()
# Out:
# array(['2', '3', '4', nan, '1', '-'], dtype=object)

# %%
df["ESTU_ESTADOINVESTIGACION"].unique()
# Out:
# array(['PUBLICAR', 'NO SE COMPROBO IDENTIDAD DEL EXAMINADO',
#        'VALIDEZ OFICINA JURÍDICA'], dtype=object)

# %%
df["ESTU_GENERACION-E"].unique()
# Out:
# array(['NO', 'GENERACION E - GRATUIDAD',
#        'GENERACION E - EXCELENCIA NACIONAL',
#        'GENERACION E - EXCELENCIA DEPARTAMENTAL'], dtype=object)

# %%
drop_cols += [
    "ESTU_TIPODOCUMENTO", #No relevante para el objetivo
    "ESTU_NACIONALIDAD", # filtra por esta columna pendiente
    "ESTU_FECHANACIMIENTO",#No relevante para el objetivo
    "ESTU_CONSECUTIVO", #No relevante para el objetivo, valores unicos
    "ESTU_ESTUDIANTE", #Todas las filas iguales
    "ESTU_TIENEETNIA", #No relevante para el objetivo
    "ESTU_ETNIA", # filtrar por esta columna
    "ESTU_COD_RESIDE_DEPTO", #Nos queamos con la columna de TEXTO del DEPTO
    "ESTU_COD_RESIDE_MCPIO", #Nos queamos con la columna de TEXTO del MCPIO
    "ESTU_PRIVADO_LIBERTAD", #filtrar por esta columna
    "ESTU_NSE_INDIVIDUAL", #No relevante para el objetivo
    "ESTU_ESTADOINVESTIGACION", #debemos filtrar por esta columna
    "ESTU_GENERACION-E", #No relevante para el objetivo
    "ESTU_PAIS_RESIDE", #No revelante, todos van a ser de COLOMBIA
    "ESTU_DEPTO_PRESENTACION", #No relevante para el objetivo
    "ESTU_MCPIO_PRESENTACION", #No relevante para el objetivo
    "ESTU_INSE_INDIVIDUAL", #No sabemos lo que representa esta variable
    "ESTU_MCPIO_RESIDE" #son mas de 900 municipios despues de un one hot encodig el dataset quedaria muy ancho
]

filters.update(
    {
        "ESTU_NACIONALIDAD": "COLOMBIA", # No tomamos las pruebas realizadas por extrangeros
        "ESTU_TIENEETNIA": "No",   # No tomamos a los estudiantes que especificaron su identidad dado que son muy pocos y quedaria desbalanceado
        "ESTU_PRIVADO_LIBERTAD": "N" # Los estudiantes provados de la libertad eran muy pocos y podrian representar valores atipicos
    }
)

# %% [markdown]
# ### Analizar columnas de texto de Fami

# %%
fami_text_Cols
# Out:
# ['FAMI_ESTRATOVIVIENDA',
#  'FAMI_PERSONASHOGAR',
#  'FAMI_CUARTOSHOGAR',
#  'FAMI_EDUCACIONPADRE',
#  'FAMI_EDUCACIONMADRE',
#  'FAMI_TRABAJOLABORPADRE',
#  'FAMI_TRABAJOLABORMADRE',
#  'FAMI_TIENEINTERNET',
#  'FAMI_TIENESERVICIOTV',
#  'FAMI_TIENECOMPUTADOR',
#  'FAMI_TIENELAVADORA',
#  'FAMI_TIENEHORNOMICROOGAS',
#  'FAMI_TIENEAUTOMOVIL',
#  'FAMI_TIENEMOTOCICLETA',
#  'FAMI_TIENECONSOLAVIDEOJUEGOS',
#  'FAMI_NUMLIBROS',
#  'FAMI_COMELECHEDERIVADOS',
#  'FAMI_COMECARNEPESCADOHUEVO',
#  'FAMI_COMECEREALFRUTOSLEGUMBRE',
#  'FAMI_SITUACIONECONOMICA']

# %%
df[fami_text_Cols].head()
# Out:
#   FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR FAMI_CUARTOSHOGAR  \
# 0            Estrato 3              5 a 6             Cinco
# 1            Estrato 3            9 o más              Tres
# 2            Estrato 1              5 a 6               Dos
# 3            Estrato 3              3 a 4               Dos
# 4            Estrato 3              3 a 4            Cuatro
#
#                   FAMI_EDUCACIONPADRE                   FAMI_EDUCACIONMADRE  \
# 0      Educación profesional completa    Secundaria (Bachillerato) completa
# 1      Técnica o tecnológica completa        Técnica o tecnológica completa
# 2  Secundaria (Bachillerato) completa    Secundaria (Bachillerato) completa
# 3                 Primaria incompleta    Secundaria (Bachillerato) completa
# 4  Secundaria (Bachillerato) completa  Secundaria (Bachillerato) incompleta
#
#                               FAMI_TRABAJOLABORPADRE  \
# 0                                          No aplica
# 1  Trabaja por cuenta propia (por ejemplo plomero...
# 2       Es vendedor o trabaja en atención al público
# 3                                          No aplica
# 4          Trabaja en el hogar, no trabaja o estudia
#
#                               FAMI_TRABAJOLABORMADRE FAMI_TIENEINTERNET  \
# 0          Trabaja en el hogar, no trabaja o estudia                 Si
# 1  Es dueño de un negocio pequeño (tiene pocos em...                 Si
# 2       Es vendedor o trabaja en atención al público                 No
# 3  Es dueño de un negocio pequeño (tiene pocos em...                 No
# 4          Trabaja en el hogar, no trabaja o estudia                 Si
#
#   FAMI_TIENESERVICIOTV FAMI_TIENECOMPUTADOR FAMI_TIENELAVADORA  \
# 0                   Si                   No                 Si
# 1                   Si                   Si                 Si
# 2                   Si                   No                 Si
# 3                   No                   Si                 No
# 4                   Si                   Si                 Si
#
#   FAMI_TIENEHORNOMICROOGAS FAMI_TIENEAUTOMOVIL FAMI_TIENEMOTOCICLETA  \
# 0                       Si                  No                    No
# 1                       Si                  Si                    No
# 2                       No                  No                    No
# 3                       No                  No                    No
# 4                       Si                  No                    No
#
#   FAMI_TIENECONSOLAVIDEOJUEGOS     FAMI_NUMLIBROS  \
# 0                           No  MÁS DE 100 LIBROS
# 1                           No  MÁS DE 100 LIBROS
# 2                           No    26 A 100 LIBROS
# 3                           No     11 A 25 LIBROS
# 4                           No    26 A 100 LIBROS
#
#        FAMI_COMELECHEDERIVADOS    FAMI_COMECARNEPESCADOHUEVO  \
# 0       1 o 2 veces por semana        3 a 5 veces por semana
# 1  Todos o casi todos los días        3 a 5 veces por semana
# 2  Todos o casi todos los días   Todos o casi todos los días
# 3  Todos o casi todos los días   Todos o casi todos los días
# 4  Todos o casi todos los días  Nunca o rara vez comemos eso
#
#   FAMI_COMECEREALFRUTOSLEGUMBRE FAMI_SITUACIONECONOMICA
# 0  Nunca o rara vez comemos eso                    Peor
# 1        1 o 2 veces por semana                   Mejor
# 2        3 a 5 veces por semana                   Igual
# 3        3 a 5 veces por semana                   Igual
# 4   Todos o casi todos los días                   Mejor

# %%
df[fami_text_Cols].describe()
# Out:
#        FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR FAMI_CUARTOSHOGAR  \
# count                546186             537749            539794
# unique                    8                  6                 7
# top               Estrato 2              3 a 4              Tres
# freq                 188314             257604            207232
#
#                        FAMI_EDUCACIONPADRE  \
# count                               537920
# unique                                  13
# top     Secundaria (Bachillerato) completa
# freq                                117488
#
#                        FAMI_EDUCACIONMADRE  \
# count                               525253
# unique                                  13
# top     Secundaria (Bachillerato) completa
# freq                                136286
#
#                      FAMI_TRABAJOLABORPADRE  \
# count                                538081
# unique                                   14
# top     Es agricultor, pesquero o jornalero
# freq                                  78187
#
#                            FAMI_TRABAJOLABORMADRE FAMI_TIENEINTERNET  \
# count                                      538743             537875
# unique                                         14                  3
# top     Trabaja en el hogar, no trabaja o estudia                 Si
# freq                                       213377             314042
#
#        FAMI_TIENESERVICIOTV FAMI_TIENECOMPUTADOR FAMI_TIENELAVADORA  \
# count                523932               538027             538569
# unique                    3                    3                  3
# top                      Si                   Si                 Si
# freq                 391419               295409             405542
#
#        FAMI_TIENEHORNOMICROOGAS FAMI_TIENEAUTOMOVIL FAMI_TIENEMOTOCICLETA  \
# count                    537582              538006                537395
# unique                        3                   3                     3
# top                          No                  No                    No
# freq                     280967              401388                308054
#
#        FAMI_TIENECONSOLAVIDEOJUEGOS FAMI_NUMLIBROS FAMI_COMELECHEDERIVADOS  \
# count                        538487         537558                  523907
# unique                            3              5                       5
# top                              No  0 A 10 LIBROS  1 o 2 veces por semana
# freq                         410475         207526                  170538
#
#          FAMI_COMECARNEPESCADOHUEVO FAMI_COMECEREALFRUTOSLEGUMBRE  \
# count                        536587                        523880
# unique                            5                             5
# top     Todos o casi todos los días        1 o 2 veces por semana
# freq                         209228                        198491
#
#        FAMI_SITUACIONECONOMICA
# count                   537953
# unique                       4
# top                      Igual
# freq                    322524

# %%
df["FAMI_SITUACIONECONOMICA"].unique()
# Out:
# array(['Peor', 'Mejor', 'Igual', '-', nan], dtype=object)

# %%
drop_cols+=[
    "FAMI_CUARTOSHOGAR", #No relevante para el objetivo
    "FAMI_TIENELAVADORA", #No relevante para el objetivo
    "FAMI_TIENEHORNOMICROOGAS", #No relevante para el objetivo
    "FAMI_TIENEAUTOMOVIL", #No relevante para el objetivo
    "FAMI_TIENEMOTOCICLETA", #No relevante para el objetivo
    "FAMI_TIENECONSOLAVIDEOJUEGOS" #No relevante para el objetivo
]

# %% [markdown]
# ### Analizar columnas de texto de Cole

# %%
df[cole_text_Cols].head()
# Out:
#                          COLE_NOMBRE_ESTABLECIMIENTO COLE_GENERO  \
# 0  INSTITUCION EDUCATIVA DEPARTAMENTAL ANTONIO BR...       MIXTO
# 1                                    GIMN SAN ANGELO       MIXTO
# 2  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.       MIXTO
# 3         COLEGIO VIRGINIA GUTIERREZ DE PINEDA (IED)       MIXTO
# 4                      COLEGIO PALERMO  IEDIP  (IED)       MIXTO
#
#   COLE_NATURALEZA COLE_CALENDARIO COLE_BILINGUE      COLE_CARACTER  \
# 0         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 1      NO OFICIAL               A             -          ACADÉMICO
# 2         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 3         OFICIAL               A             -          ACADÉMICO
# 4         OFICIAL               A             N  TÉCNICO/ACADÉMICO
#
#                                     COLE_NOMBRE_SEDE COLE_SEDE_PRINCIPAL  \
# 0                   COL DPTAL ANTONIO BRUGES CARMONA                   S
# 1                                    GIMN SAN ANGELO                   S
# 2  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.                   S
# 3   COL VIRGINIA GUTIERREZ DE PINEDA (INS EDUC DIST)                   S
# 4                       CENT EDUC DIST PALERMO CEDIP                   S
#
#   COLE_AREA_UBICACION COLE_JORNADA COLE_MCPIO_UBICACION COLE_DEPTO_UBICACION
# 0              URBANO       MAÑANA            SANTA ANA            MAGDALENA
# 1              URBANO     COMPLETA          BOGOTÁ D.C.               BOGOTÁ
# 2              URBANO       MAÑANA  CARTAGENA DE INDIAS              BOLIVAR
# 3              URBANO       MAÑANA          BOGOTÁ D.C.               BOGOTÁ
# 4              URBANO       MAÑANA          BOGOTÁ D.C.               BOGOTÁ

# %%
df[cole_text_Cols].describe()
# Out:
#                            COLE_NOMBRE_ESTABLECIMIENTO COLE_GENERO  \
# count                                           546212      546212
# unique                                            9372           3
# top     INSTITUCION EDUCATIVA FRANCISCO JOSE DE CALDAS       MIXTO
# freq                                              1147      528780
#
#        COLE_NATURALEZA COLE_CALENDARIO COLE_BILINGUE COLE_CARACTER  \
# count           546212          546212        546212        532464
# unique               2               3             3             5
# top            OFICIAL               A             N     ACADÉMICO
# freq            416011          541901        453280        284200
#
#                     COLE_NOMBRE_SEDE COLE_SEDE_PRINCIPAL COLE_AREA_UBICACION  \
# count                         546212              546212              546212
# unique                         10284                   2                   2
# top     INSTITUTO TECNICO INDUSTRIAL                   S              URBANO
# freq                             881              523322              460467
#
#        COLE_JORNADA COLE_MCPIO_UBICACION COLE_DEPTO_UBICACION
# count        546212               546212               546212
# unique            6                 1030                   33
# top          MAÑANA          BOGOTÁ D.C.               BOGOTÁ
# freq         257060                82832                82832

# %%
df["COLE_NATURALEZA"].unique()
# Out:
# array(['OFICIAL', 'NO OFICIAL'], dtype=object)

# %%
df["COLE_CARACTER"].unique()
# Out:
# array(['TÉCNICO/ACADÉMICO', 'ACADÉMICO', nan, 'TÉCNICO', 'NO APLICA', '-'],
#       dtype=object)

# %%
df["COLE_JORNADA"].unique()
# Out:
# array(['MAÑANA', 'COMPLETA', 'NOCHE', 'UNICA', 'TARDE', 'SABATINA'],
#       dtype=object)

# %%
drop_cols+=[
    "COLE_NOMBRE_ESTABLECIMIENTO", #valores unicos
    "COLE_GENERO",          #filtrar por mixto categoria dominante
    "COLE_NATURALEZA",
    "COLE_CALENDARIO",      #filtramos A
    "COLE_BILINGUE",        #No relevante para el objetivo
    "COLE_CARACTER",        #No relevante para el objetivo
    "COLE_NOMBRE_SEDE",     #No relevante para el objetivo valores unicos}
    "COLE_SEDE_PRINCIPAL",  #No relevante para el objetivo
    "COLE_MCPIO_UBICACION", #No relevante para el objetivo ya tango esta info del estudiante
    "COLE_DEPTO_UBICACION", #No relevante para el objetivo ya tango esta info del estudiante
    "COLE_AREA_UBICACION",
    "COLE_JORNADA"

]

filters.update(
    {
        "COLE_GENERO": "MIXTO",  # Esta variable categoria esta muy desvalanceada y escoger solo los colegios mixtos no afecta mucho el numero de registros
        "COLE_CALENDARIO": "A",   # Esta variable categoria esta muy desvalanceada y escoger solo los collegios con calendario A no afecta mucho el numero de registros
        "COLE_AREA_UBICACION": "URBANO" # Esta variable categoria esta muy desvalanceada y escoger solo los colegios urbanos no afecta mucho el numero de registros
    }
)

# %% [markdown]
# ### Analizar columnas de texto de Restantes

# %%
df[restante_texto_cols].head()
# Out:
#   DESEMP_INGLES PERCENTIL_GLOBAL
# 0            A1               25
# 1            A2               83
# 2            A2               84
# 3            A1               88
# 4            A1               78

# %%
df[restante_texto_cols].describe()
# Out:
#        DESEMP_INGLES PERCENTIL_GLOBAL
# count         546212           546212
# unique             5              101
# top               A-               22
# freq          271183             6443

# %%
df['DESEMP_INGLES'].unique()
# Out:
# array(['A1', 'A2', 'A-', 'B1', 'B+'], dtype=object)

# %%
df['PERCENTIL_GLOBAL'].unique()
# Out:
# array(['25', '83', '84', '88', '78', '19', '99', '89', '95', '13', '5',
#        '85', '74', '33', '67', '91', '64', '43', '46', '80', '49', '63',
#        '6', '98', '72', '45', '20', '27', '57', '59', '60', '65', '2',
#        '75', '9', '86', '92', '55', '81', '38', '76', '28', '41', '22',
#        '97', '51', '61', '94', '90', '96', '15', '21', '62', '39', '87',
#        '18', '79', '31', '42', '82', '7', '3', '71', '35', '37', '17',
#        '26', '12', '16', '93', '24', '73', '48', '30', '58', '50', '56',
#        '77', '11', '40', '66', '36', '52', '10', '47', '1', '4', '53',
#        '8', '29', '14', '34', '70', '100', '54', '32', '68', '23', '44',
#        '69', '-'], dtype=object)

# %%
drop_cols+=[
    "DESEMP_INGLES", #No relevante para el objetivo
    "PERCENTIL_GLOBAL" #No relevante para el objetivo
]

# %% [markdown]
# ## Columnas Numericas

# %%
# listamos todas las columnas de numeros
num_cols=df.select_dtypes(include = ['float64','int32','int64']).columns.tolist()
estu_num_cols = list(filter(lambda x: 'ESTU' in x, num_cols))
fami_num_Cols = list(filter(lambda x: 'FAMI' in x, num_cols))
cole_num_Cols = list(filter(lambda x: 'COLE' in x, num_cols)) # Columnas con información del colegio del estudiante
restante_num_cols = list(filter(lambda x: not 'ESTU' in x and not 'FAMI' in x and not 'COLE' in x, num_cols))

# %% [markdown]
# ### Analizar columnas de numericas de Estu

# %%
estu_num_cols
# Out:
# ['ESTU_COD_MCPIO_PRESENTACION',
#  'ESTU_COD_DEPTO_PRESENTACION',
#  'ESTU_NSE_ESTABLECIMIENTO']

# %%
df[estu_num_cols].head()
# Out:
#    ESTU_COD_MCPIO_PRESENTACION  ESTU_COD_DEPTO_PRESENTACION  \
# 0                        47707                           47
# 1                        11001                           11
# 2                        13001                           13
# 3                        11001                           11
# 4                        11001                           11
#
#    ESTU_NSE_ESTABLECIMIENTO
# 0                       2.0
# 1                       4.0
# 2                       3.0
# 3                       3.0
# 4                       3.0

# %%
drop_cols += estu_num_cols # Codigos que no se usan para operaciones matematicas

# %% [markdown]
# ### Analizar columnas de numericas de Fami

# %%
fami_num_Cols
# Out:
# []

# %% [markdown]
# ### Analizar columnas de numericas de Cole

# %%
cole_num_Cols
# Out:
# ['COLE_CODIGO_ICFES',
#  'COLE_COD_DANE_ESTABLECIMIENTO',
#  'COLE_COD_DANE_SEDE',
#  'COLE_COD_MCPIO_UBICACION',
#  'COLE_COD_DEPTO_UBICACION']

# %%
df[cole_num_Cols].head()
# Out:
#    COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# 0              39008                   147707000156        147707000156
# 1             128611                   311001105383        311001105383
# 2              35493                   113001001719        113001001719
# 3             138032                   111001107069        111001107069
# 4             217406                   111001094897        111001094897
#
#    COLE_COD_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION
# 0                     47707                        47
# 1                     11001                        11
# 2                     13001                        13
# 3                     11001                        11
# 4                     11001                        11

# %%
drop_cols += cole_num_Cols # Ninguna de estas columnas es verdaderamente numerica y no son relevantes para el objetivo

# %% [markdown]
# No hay columnas de FAMI númericas

# %% [markdown]
# ### Analizar columnas de numericas Restantes

# %%
df[restante_num_cols].head()
# Out:
#    PERIODO  PUNT_LECTURA_CRITICA  PERCENTIL_LECTURA_CRITICA  \
# 0    20194                    47                         33
# 1    20194                    60                         76
# 2    20194                    66                         91
# 3    20194                    62                         81
# 4    20194                    63                         85
#
#    DESEMP_LECTURA_CRITICA  PUNT_MATEMATICAS  PERCENTIL_MATEMATICAS  \
# 0                       2                48                     42
# 1                       3                65                     88
# 2                       4                57                     70
# 3                       3                54                     60
# 4                       3                57                     70
#
#    DESEMP_MATEMATICAS  PUNT_C_NATURALES  PERCENTIL_C_NATURALES  \
# 0                   2                37                     15
# 1                   3                54                     71
# 2                   3                41                     29
# 3                   3                61                     87
# 4                   3                55                     74
#
#    DESEMP_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  \
# 0                   1                        30
# 1                   2                        59
# 2                   2                        74
# 3                   3                        73
# 4                   2                        57
#
#    PERCENTIL_SOCIALES_CIUDADANAS  DESEMP_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# 0                              8                           1         54.0
# 1                             83                           3         63.0
# 2                             99                           4         64.0
# 3                             99                           4         53.0
# 4                             79                           3         52.0
#
#    PERCENTIL_INGLES  PUNT_GLOBAL
# 0                67          208
# 1                88          299
# 2                89          299
# 3                67          309
# 4                63          288

# %%
drop_cols+=[
    "PERIODO", # No relevante para el objetivo
    "PERCENTIL_LECTURA_CRITICA", # No relevante para el objetivo
    "DESEMP_LECTURA_CRITICA", # No relevante para el objetivo
    "PERCENTIL_MATEMATICAS", # No relevante para el objetivo
    "DESEMP_MATEMATICAS", # No relevante para el objetivo
    "PERCENTIL_C_NATURALES",# No relevante para el objetivo
    "DESEMP_C_NATURALES", # No relevante para el objetivo
    "PERCENTIL_SOCIALES_CIUDADANAS",#No relevante para el objetivo
    "DESEMP_SOCIALES_CIUDADANAS", # No relevante para el objetivo
    "PERCENTIL_INGLES" # No relevante para el objetivo
]

# %% [markdown]
# # Filtrado de filas

# %%
def filtrar(df, filtros):
    """
    Función para filtrar filas de un dataframe de pandas
    """
    filtered_df = df
    for key in filtros:
        filtered_df = filtered_df[filtered_df[key] == filtros[key]]

    return filtered_df

# %%
df_filtrado = filtrar(df, filters)
df_filtrado = df_filtrado.dropna()

# %% [markdown]
# # Eliminación de Columnas

# %%
df_filtrado = df_filtrado.drop(drop_cols, axis=1)
df_filtrado = df_filtrado.reindex(sorted(df_filtrado.columns), axis=1)
df_filtrado
# Out:
#        ESTU_DEDICACIONINTERNET ESTU_DEDICACIONLECTURADIARIA ESTU_DEPTO_RESIDE  \
# 0        Entre 30 y 60 minutos        Entre 30 y 60 minutos         MAGDALENA
# 1        Entre 30 y 60 minutos        Entre 30 y 60 minutos            BOGOTÁ
# 2               Más de 3 horas        Entre 30 y 60 minutos           BOLIVAR
# 4               Más de 3 horas   No leo por entretenimiento            BOGOTÁ
# 7               Más de 3 horas            Entre 1 y 2 horas         SANTANDER
# ...                        ...                          ...               ...
# 546207          Más de 3 horas   No leo por entretenimiento         ANTIOQUIA
# 546208          Más de 3 horas   No leo por entretenimiento            BOGOTÁ
# 546209   Entre 30 y 60 minutos           30 minutos o menos            ARAUCA
# 546210   Entre 30 y 60 minutos           30 minutos o menos         SANTANDER
# 546211       Entre 1 y 3 horas        Entre 30 y 60 minutos            BOGOTÁ
#
#        ESTU_GENERO ESTU_HORASSEMANATRABAJA      ESTU_TIPOREMUNERACION  \
# 0                M       Menos de 10 horas            Si, en efectivo
# 1                M       Menos de 10 horas            Si, en efectivo
# 2                M                       0            Si, en efectivo
# 4                M         Más de 30 horas                         No
# 7                M       Menos de 10 horas            Si, en efectivo
# ...            ...                     ...                        ...
# 546207           M       Menos de 10 horas  Si, en efectivo y especie
# 546208           M                       0                         No
# 546209           M                       0                         No
# 546210           M         Más de 30 horas            Si, en efectivo
# 546211           M                       0                         No
#
#           FAMI_COMECARNEPESCADOHUEVO FAMI_COMECEREALFRUTOSLEGUMBRE  \
# 0             3 a 5 veces por semana  Nunca o rara vez comemos eso
# 1             3 a 5 veces por semana        1 o 2 veces por semana
# 2        Todos o casi todos los días        3 a 5 veces por semana
# 4       Nunca o rara vez comemos eso   Todos o casi todos los días
# 7             3 a 5 veces por semana        3 a 5 veces por semana
# ...                              ...                           ...
# 546207   Todos o casi todos los días        1 o 2 veces por semana
# 546208        3 a 5 veces por semana        3 a 5 veces por semana
# 546209   Todos o casi todos los días        3 a 5 veces por semana
# 546210   Todos o casi todos los días        1 o 2 veces por semana
# 546211   Todos o casi todos los días        3 a 5 veces por semana
#
#             FAMI_COMELECHEDERIVADOS                   FAMI_EDUCACIONMADRE  \
# 0            1 o 2 veces por semana    Secundaria (Bachillerato) completa
# 1       Todos o casi todos los días        Técnica o tecnológica completa
# 2       Todos o casi todos los días    Secundaria (Bachillerato) completa
# 4       Todos o casi todos los días  Secundaria (Bachillerato) incompleta
# 7            1 o 2 veces por semana        Educación profesional completa
# ...                             ...                                   ...
# 546207       1 o 2 veces por semana    Secundaria (Bachillerato) completa
# 546208  Todos o casi todos los días                     Primaria completa
# 546209  Todos o casi todos los días        Técnica o tecnológica completa
# 546210       3 a 5 veces por semana  Secundaria (Bachillerato) incompleta
# 546211       3 a 5 veces por semana        Técnica o tecnológica completa
#
#                        FAMI_EDUCACIONPADRE FAMI_ESTRATOVIVIENDA  \
# 0           Educación profesional completa            Estrato 3
# 1           Técnica o tecnológica completa            Estrato 3
# 2       Secundaria (Bachillerato) completa            Estrato 1
# 4       Secundaria (Bachillerato) completa            Estrato 3
# 7           Educación profesional completa            Estrato 3
# ...                                    ...                  ...
# 546207                 Primaria incompleta            Estrato 2
# 546208                             No sabe            Estrato 3
# 546209                           Postgrado            Estrato 2
# 546210                 Primaria incompleta            Estrato 1
# 546211  Secundaria (Bachillerato) completa            Estrato 3
#
#            FAMI_NUMLIBROS FAMI_PERSONASHOGAR FAMI_SITUACIONECONOMICA  \
# 0       MÁS DE 100 LIBROS              5 a 6                    Peor
# 1       MÁS DE 100 LIBROS            9 o más                   Mejor
# 2         26 A 100 LIBROS              5 a 6                   Igual
# 4         26 A 100 LIBROS              3 a 4                   Mejor
# 7       MÁS DE 100 LIBROS              3 a 4                   Igual
# ...                   ...                ...                     ...
# 546207      0 A 10 LIBROS              5 a 6                   Igual
# 546208     11 A 25 LIBROS              5 a 6                   Mejor
# 546209    26 A 100 LIBROS              5 a 6                   Igual
# 546210      0 A 10 LIBROS              3 a 4                   Igual
# 546211     11 A 25 LIBROS              3 a 4                   Igual
#
#        FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET FAMI_TIENESERVICIOTV  \
# 0                        No                 Si                   Si
# 1                        Si                 Si                   Si
# 2                        No                 No                   Si
# 4                        Si                 Si                   Si
# 7                        Si                 Si                   Si
# ...                     ...                ...                  ...
# 546207                   Si                 Si                   Si
# 546208                   Si                 Si                   Si
# 546209                   Si                 Si                   Si
# 546210                   No                 No                   Si
# 546211                   No                 Si                   Si
#
#                                    FAMI_TRABAJOLABORMADRE  \
# 0               Trabaja en el hogar, no trabaja o estudia
# 1       Es dueño de un negocio pequeño (tiene pocos em...
# 2            Es vendedor o trabaja en atención al público
# 4               Trabaja en el hogar, no trabaja o estudia
# 7               Trabaja en el hogar, no trabaja o estudia
# ...                                                   ...
# 546207  Trabaja por cuenta propia (por ejemplo plomero...
# 546208       Es vendedor o trabaja en atención al público
# 546209       Es vendedor o trabaja en atención al público
# 546210  Trabaja como personal de limpieza, mantenimien...
# 546211                                          No aplica
#
#                                    FAMI_TRABAJOLABORPADRE  PUNT_C_NATURALES  \
# 0                                               No aplica                37
# 1       Trabaja por cuenta propia (por ejemplo plomero...                54
# 2            Es vendedor o trabaja en atención al público                41
# 4               Trabaja en el hogar, no trabaja o estudia                55
# 7       Tiene un trabajo de tipo auxiliar administrati...                63
# ...                                                   ...               ...
# 546207  Trabaja por cuenta propia (por ejemplo plomero...                65
# 546208                                            No sabe                72
# 546209  Trabaja como profesional (por ejemplo médico, ...                71
# 546210  Trabaja como personal de limpieza, mantenimien...                54
# 546211                                            No sabe                72
#
#         PUNT_GLOBAL  PUNT_INGLES  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# 0               208         54.0                    47                48
# 1               299         63.0                    60                65
# 2               299         64.0                    66                57
# 4               288         52.0                    63                57
# 7               313         60.0                    57                65
# ...             ...          ...                   ...               ...
# 546207          360         58.0                    76                78
# 546208          360         74.0                    75                73
# 546209          377         72.0                    72                83
# 546210          278         46.0                    59                61
# 546211          365         74.0                    76                73
#
#         PUNT_SOCIALES_CIUDADANAS
# 0                             30
# 1                             59
# 2                             74
# 4                             57
# 7                             66
# ...                          ...
# 546207                        74
# 546208                        67
# 546209                        77
# 546210                        52
# 546211                        71
#
# [372035 rows x 26 columns]

# %% [markdown]
# Se eliminan los valores "-" dado que en este dataset es la forma de definir los Null

# %%
print(len(df_filtrado))
for i in df_filtrado.columns:
    if "-" in df_filtrado[i].unique():
        df_filtrado = df_filtrado[df_filtrado[i] != "-"]
print(len(df_filtrado))
# Out:
# 372035
# 347677

# %%
df_filtrado.columns
# Out:
# Index(['ESTU_DEDICACIONINTERNET', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEPTO_RESIDE', 'ESTU_GENERO', 'ESTU_HORASSEMANATRABAJA',
#        'ESTU_TIPOREMUNERACION', 'FAMI_COMECARNEPESCADOHUEVO',
#        'FAMI_COMECEREALFRUTOSLEGUMBRE', 'FAMI_COMELECHEDERIVADOS',
#        'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE', 'FAMI_ESTRATOVIVIENDA',
#        'FAMI_NUMLIBROS', 'FAMI_PERSONASHOGAR', 'FAMI_SITUACIONECONOMICA',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_TRABAJOLABORPADRE', 'PUNT_C_NATURALES',
#        'PUNT_GLOBAL', 'PUNT_INGLES', 'PUNT_LECTURA_CRITICA',
#        'PUNT_MATEMATICAS', 'PUNT_SOCIALES_CIUDADANAS'],
#       dtype='object')

# %% [markdown]
# # Encoding

# %% [markdown]
# ## Label Ordinary Encoding

# %%
def orderEncode(df,categ,col):
    df2 = df
    for i in categ:
        df2[col] = df2[col].replace(categ,range(len(categ)))
    return df2[col]

# %%
df_encoded = df_filtrado

#------------ESTU_DEDICACIONINTERNET-----------------

categorias = [
    "No Navega Internet",
    "30 minutos o menos",
    "Entre 30 y 60 minutos",
    "Entre 1 y 3 horas",
    "Más de 3 horas"
]

df_encoded["ESTU_DEDICACIONINTERNET"] = orderEncode(df_encoded,categorias,"ESTU_DEDICACIONINTERNET")

#-------------ESTU_DEDICACIONLECTURADIARIA--------------


categorias = [
    "No leo por entretenimiento",
    "30 minutos o menos",
    "Entre 30 y 60 minutos",
    "Entre 1 y 2 horas",
    "Más de 2 horas"
]

df_encoded["ESTU_DEDICACIONLECTURADIARIA"] = orderEncode(df_encoded,categorias,"ESTU_DEDICACIONLECTURADIARIA")

#----------------ESTU_HORASSEMANATRABAJA--------------------

categorias = [
    '0',
    'Menos de 10 horas',
    'Entre 11 y 20 horas',
    'Entre 21 y 30 horas',
    'Más de 30 horas'
]

df_encoded["ESTU_HORASSEMANATRABAJA"] = orderEncode(df_encoded,categorias,"ESTU_HORASSEMANATRABAJA")

#----------------FAMI_COMECARNEPESCADOHUEVO  &  FAMI_COMECEREALFRUTOSLEGUMBRE & FAMI_COMELECHEDERIVADOS--------------------

categorias = [
    'Nunca o rara vez comemos eso',
    '1 o 2 veces por semana',
    '3 a 5 veces por semana',
    'Todos o casi todos los días'
]

df_encoded["FAMI_COMECARNEPESCADOHUEVO"] = orderEncode(df_encoded,categorias,"FAMI_COMECARNEPESCADOHUEVO")
df_encoded["FAMI_COMECEREALFRUTOSLEGUMBRE"] = orderEncode(df_encoded,categorias,"FAMI_COMECEREALFRUTOSLEGUMBRE")
df_encoded["FAMI_COMELECHEDERIVADOS"] = orderEncode(df_encoded,categorias,"FAMI_COMELECHEDERIVADOS")

#-----------------------FAMI_EDUCACIONMADRE & FAMI_EDUCACIONPADRE--------------------------------

categorias = [
    'No Aplica',
    'Ninguno',
    'No sabe',
    'Primaria incompleta',
    'Primaria completa',
    'Secundaria (Bachillerato) incompleta',
    'Secundaria (Bachillerato) completa',
    'Técnica o tecnológica incompleta',
    'Técnica o tecnológica completa',
    'Educación profesional incompleta',
    'Educación profesional completa',
    'Postgrado'
]

df_encoded["FAMI_EDUCACIONMADRE"] = orderEncode(df_encoded,categorias,"FAMI_EDUCACIONMADRE")
df_encoded["FAMI_EDUCACIONPADRE"] = orderEncode(df_encoded,categorias,"FAMI_EDUCACIONPADRE")

#-------------------------------FAMI_ESTRATOVIVIENDA--------------------------

categorias = [
    'Sin Estrato',
    'Estrato 1',
    'Estrato 2',
    'Estrato 3',
    'Estrato 4',
    'Estrato 5',
    'Estrato 6'
]

df_encoded["FAMI_ESTRATOVIVIENDA"] = orderEncode(df_encoded,categorias,"FAMI_ESTRATOVIVIENDA")


#----------------------------------FAMI_NUMLIBROS--------------------------------

categorias = [
    '0 A 10 LIBROS',
    '11 A 25 LIBROS',
    '26 A 100 LIBROS',
    'MÁS DE 100 LIBROS'
]

df_encoded["FAMI_NUMLIBROS"] = orderEncode(df_encoded,categorias,"FAMI_NUMLIBROS")

#----------------------------------FAMI_PERSONASHOGAR--------------------------------

categorias = [
    '1 a 2',
    '3 a 4',
    '5 a 6',
    '7 a 8',
    '9 o más'
]

df_encoded["FAMI_PERSONASHOGAR"] = orderEncode(df_encoded,categorias,"FAMI_PERSONASHOGAR")

#----------------------------------FAMI_SITUACIONECONOMICA--------------------------------

categorias = [
    "Peor",
    "Igual",
    "Mejor"
]

df_encoded["FAMI_SITUACIONECONOMICA"] = orderEncode(df_encoded,categorias,"FAMI_SITUACIONECONOMICA")

#----------------------------------FAMI_TIENECOMPUTADOR & FAMI_TIENEINTERNET & FAMI_TIENESERVICIOTV & --------------------------------

categorias = [
    "No",
    "Si",
]

df_encoded["FAMI_TIENECOMPUTADOR"] = orderEncode(df_encoded,categorias,"FAMI_TIENECOMPUTADOR")
df_encoded["FAMI_TIENEINTERNET"] = orderEncode(df_encoded,categorias,"FAMI_TIENEINTERNET")
df_encoded["FAMI_TIENESERVICIOTV"] = orderEncode(df_encoded,categorias,"FAMI_TIENESERVICIOTV")

#----------------------------------ESTU_TIPOREMUNERACION--------------------------------
categorias = [
    "No",
    "Si, en especie",
    "Si, en efectivo y especie",
    "Si, en efectivo"
]

df_encoded["ESTU_TIPOREMUNERACION"] = orderEncode(df_encoded,categorias,"ESTU_TIPOREMUNERACION")

#------------------------------------------FAMI_TRABAJOLABORMADRE  &  FAMI_TRABAJOLABORPADRE-------------------------------

categorias = [
    'No sabe',
    'No aplica',
    'Trabaja en el hogar, no trabaja o estudia',
    'Trabaja como personal de limpieza, mantenimiento, seguridad o construcción',
    'Es agricultor, pesquero o jornalero',
    'Es operario de máquinas o conduce vehículos (taxita, chofer)',
    'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc',
    'Es vendedor o trabaja en atención al público',
    'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)',
    'Trabaja por cuenta propia (por ejemplo plomero, electricista)',
    'Pensionado',
    'Trabaja como profesional (por ejemplo médico, abogado, ingeniero)',
    'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial'
]

df_encoded["FAMI_TRABAJOLABORMADRE"] = orderEncode(df_encoded,categorias,"FAMI_TRABAJOLABORMADRE")
df_encoded["FAMI_TRABAJOLABORPADRE"] = orderEncode(df_encoded,categorias,"FAMI_TRABAJOLABORPADRE")

# %% [markdown]
# ## One-Hot Encoding

# %%
df_encoded = pd.get_dummies(df_encoded, columns = ['ESTU_DEPTO_RESIDE', 'ESTU_GENERO'], dtype=int).drop("ESTU_GENERO_F",axis=1)
text_cols = df.select_dtypes(include = ["object", 'category']).columns.tolist()
# se elimmina una de las columnas de generao dado que entregaria datos redundantes

# %%
df_encoded
# Out:
#         ESTU_DEDICACIONINTERNET  ESTU_DEDICACIONLECTURADIARIA  \
# 0                             2                             2
# 1                             2                             2
# 2                             4                             2
# 4                             4                             0
# 7                             4                             3
# ...                         ...                           ...
# 546207                        4                             0
# 546208                        4                             0
# 546209                        2                             1
# 546210                        2                             1
# 546211                        3                             2
#
#         ESTU_HORASSEMANATRABAJA  ESTU_TIPOREMUNERACION  \
# 0                             1                      3
# 1                             1                      3
# 2                             0                      3
# 4                             4                      0
# 7                             1                      3
# ...                         ...                    ...
# 546207                        1                      2
# 546208                        0                      0
# 546209                        0                      0
# 546210                        4                      3
# 546211                        0                      0
#
#         FAMI_COMECARNEPESCADOHUEVO  FAMI_COMECEREALFRUTOSLEGUMBRE  \
# 0                                2                              0
# 1                                2                              1
# 2                                3                              2
# 4                                0                              3
# 7                                2                              2
# ...                            ...                            ...
# 546207                           3                              1
# 546208                           2                              2
# 546209                           3                              2
# 546210                           3                              1
# 546211                           3                              2
#
#         FAMI_COMELECHEDERIVADOS  FAMI_EDUCACIONMADRE  FAMI_EDUCACIONPADRE  \
# 0                             1                    6                   10
# 1                             3                    8                    8
# 2                             3                    6                    6
# 4                             3                    5                    6
# 7                             1                   10                   10
# ...                         ...                  ...                  ...
# 546207                        1                    6                    3
# 546208                        3                    4                    2
# 546209                        3                    8                   11
# 546210                        2                    5                    3
# 546211                        2                    8                    6
#
#         FAMI_ESTRATOVIVIENDA  FAMI_NUMLIBROS  FAMI_PERSONASHOGAR  \
# 0                          3               3                   2
# 1                          3               3                   4
# 2                          1               2                   2
# 4                          3               2                   1
# 7                          3               3                   1
# ...                      ...             ...                 ...
# 546207                     2               0                   2
# 546208                     3               1                   2
# 546209                     2               2                   2
# 546210                     1               0                   1
# 546211                     3               1                   1
#
#         FAMI_SITUACIONECONOMICA  FAMI_TIENECOMPUTADOR  FAMI_TIENEINTERNET  \
# 0                             0                     0                   1
# 1                             2                     1                   1
# 2                             1                     0                   0
# 4                             2                     1                   1
# 7                             1                     1                   1
# ...                         ...                   ...                 ...
# 546207                        1                     1                   1
# 546208                        2                     1                   1
# 546209                        1                     1                   1
# 546210                        1                     0                   0
# 546211                        1                     0                   1
#
#         FAMI_TIENESERVICIOTV  FAMI_TRABAJOLABORMADRE  FAMI_TRABAJOLABORPADRE  \
# 0                          1                       2                       1
# 1                          1                       6                       9
# 2                          1                       7                       7
# 4                          1                       2                       2
# 7                          1                       2                       8
# ...                      ...                     ...                     ...
# 546207                     1                       9                       9
# 546208                     1                       7                       0
# 546209                     1                       7                      11
# 546210                     1                       3                       3
# 546211                     1                       1                       0
#
#         PUNT_C_NATURALES  PUNT_GLOBAL  PUNT_INGLES  PUNT_LECTURA_CRITICA  \
# 0                     37          208         54.0                    47
# 1                     54          299         63.0                    60
# 2                     41          299         64.0                    66
# 4                     55          288         52.0                    63
# 7                     63          313         60.0                    57
# ...                  ...          ...          ...                   ...
# 546207                65          360         58.0                    76
# 546208                72          360         74.0                    75
# 546209                71          377         72.0                    72
# 546210                54          278         46.0                    59
# 546211                72          365         74.0                    76
#
#         PUNT_MATEMATICAS  PUNT_SOCIALES_CIUDADANAS  \
# 0                     48                        30
# 1                     65                        59
# 2                     57                        74
# 4                     57                        57
# 7                     65                        66
# ...                  ...                       ...
# 546207                78                        74
# 546208                73                        67
# 546209                83                        77
# 546210                61                        52
# 546211                73                        71
#
#         ESTU_DEPTO_RESIDE_AMAZONAS  ESTU_DEPTO_RESIDE_ANTIOQUIA  \
# 0                                0                            0
# 1                                0                            0
# 2                                0                            0
# 4                                0                            0
# 7                                0                            0
# ...                            ...                          ...
# 546207                           0                            1
# 546208                           0                            0
# 546209                           0                            0
# 546210                           0                            0
# 546211                           0                            0
#
#         ESTU_DEPTO_RESIDE_ARAUCA  ESTU_DEPTO_RESIDE_ATLANTICO  \
# 0                              0                            0
# 1                              0                            0
# 2                              0                            0
# 4                              0                            0
# 7                              0                            0
# ...                          ...                          ...
# 546207                         0                            0
# 546208                         0                            0
# 546209                         1                            0
# 546210                         0                            0
# 546211                         0                            0
#
#         ESTU_DEPTO_RESIDE_BOGOTÁ  ESTU_DEPTO_RESIDE_BOLIVAR  \
# 0                              0                          0
# 1                              1                          0
# 2                              0                          1
# 4                              1                          0
# 7                              0                          0
# ...                          ...                        ...
# 546207                         0                          0
# 546208                         1                          0
# 546209                         0                          0
# 546210                         0                          0
# 546211                         1                          0
#
#         ESTU_DEPTO_RESIDE_BOYACA  ESTU_DEPTO_RESIDE_CALDAS  \
# 0                              0                         0
# 1                              0                         0
# 2                              0                         0
# 4                              0                         0
# 7                              0                         0
# ...                          ...                       ...
# 546207                         0                         0
# 546208                         0                         0
# 546209                         0                         0
# 546210                         0                         0
# 546211                         0                         0
#
#         ESTU_DEPTO_RESIDE_CAQUETA  ESTU_DEPTO_RESIDE_CASANARE  \
# 0                               0                           0
# 1                               0                           0
# 2                               0                           0
# 4                               0                           0
# 7                               0                           0
# ...                           ...                         ...
# 546207                          0                           0
# 546208                          0                           0
# 546209                          0                           0
# 546210                          0                           0
# 546211                          0                           0
#
#         ESTU_DEPTO_RESIDE_CAUCA  ESTU_DEPTO_RESIDE_CESAR  \
# 0                             0                        0
# 1                             0                        0
# 2                             0                        0
# 4                             0                        0
# 7                             0                        0
# ...                         ...                      ...
# 546207                        0                        0
# 546208                        0                        0
# 546209                        0                        0
# 546210                        0                        0
# 546211                        0                        0
#
#         ESTU_DEPTO_RESIDE_CHOCO  ESTU_DEPTO_RESIDE_CORDOBA  \
# 0                             0                          0
# 1                             0                          0
# 2                             0                          0
# 4                             0                          0
# 7                             0                          0
# ...                         ...                        ...
# 546207                        0                          0
# 546208                        0                          0
# 546209                        0                          0
# 546210                        0                          0
# 546211                        0                          0
#
#         ESTU_DEPTO_RESIDE_CUNDINAMARCA  ESTU_DEPTO_RESIDE_EXTRANJERO  \
# 0                                    0                             0
# 1                                    0                             0
# 2                                    0                             0
# 4                                    0                             0
# 7                                    0                             0
# ...                                ...                           ...
# 546207                               0                             0
# 546208                               0                             0
# 546209                               0                             0
# 546210                               0                             0
# 546211                               0                             0
#
#         ESTU_DEPTO_RESIDE_GUAINIA  ESTU_DEPTO_RESIDE_GUAVIARE  \
# 0                               0                           0
# 1                               0                           0
# 2                               0                           0
# 4                               0                           0
# 7                               0                           0
# ...                           ...                         ...
# 546207                          0                           0
# 546208                          0                           0
# 546209                          0                           0
# 546210                          0                           0
# 546211                          0                           0
#
#         ESTU_DEPTO_RESIDE_HUILA  ESTU_DEPTO_RESIDE_LA GUAJIRA  \
# 0                             0                             0
# 1                             0                             0
# 2                             0                             0
# 4                             0                             0
# 7                             0                             0
# ...                         ...                           ...
# 546207                        0                             0
# 546208                        0                             0
# 546209                        0                             0
# 546210                        0                             0
# 546211                        0                             0
#
#         ESTU_DEPTO_RESIDE_MAGDALENA  ESTU_DEPTO_RESIDE_META  \
# 0                                 1                       0
# 1                                 0                       0
# 2                                 0                       0
# 4                                 0                       0
# 7                                 0                       0
# ...                             ...                     ...
# 546207                            0                       0
# 546208                            0                       0
# 546209                            0                       0
# 546210                            0                       0
# 546211                            0                       0
#
#         ESTU_DEPTO_RESIDE_NARIÑO  ESTU_DEPTO_RESIDE_NORTE SANTANDER  \
# 0                              0                                  0
# 1                              0                                  0
# 2                              0                                  0
# 4                              0                                  0
# 7                              0                                  0
# ...                          ...                                ...
# 546207                         0                                  0
# 546208                         0                                  0
# 546209                         0                                  0
# 546210                         0                                  0
# 546211                         0                                  0
#
#         ESTU_DEPTO_RESIDE_PUTUMAYO  ESTU_DEPTO_RESIDE_QUINDIO  \
# 0                                0                          0
# 1                                0                          0
# 2                                0                          0
# 4                                0                          0
# 7                                0                          0
# ...                            ...                        ...
# 546207                           0                          0
# 546208                           0                          0
# 546209                           0                          0
# 546210                           0                          0
# 546211                           0                          0
#
#         ESTU_DEPTO_RESIDE_RISARALDA  ESTU_DEPTO_RESIDE_SAN ANDRES  \
# 0                                 0                             0
# 1                                 0                             0
# 2                                 0                             0
# 4                                 0                             0
# 7                                 0                             0
# ...                             ...                           ...
# 546207                            0                             0
# 546208                            0                             0
# 546209                            0                             0
# 546210                            0                             0
# 546211                            0                             0
#
#         ESTU_DEPTO_RESIDE_SANTANDER  ESTU_DEPTO_RESIDE_SUCRE  \
# 0                                 0                        0
# 1                                 0                        0
# 2                                 0                        0
# 4                                 0                        0
# 7                                 1                        0
# ...                             ...                      ...
# 546207                            0                        0
# 546208                            0                        0
# 546209                            0                        0
# 546210                            1                        0
# 546211                            0                        0
#
#         ESTU_DEPTO_RESIDE_TOLIMA  ESTU_DEPTO_RESIDE_VALLE  \
# 0                              0                        0
# 1                              0                        0
# 2                              0                        0
# 4                              0                        0
# 7                              0                        0
# ...                          ...                      ...
# 546207                         0                        0
# 546208                         0                        0
# 546209                         0                        0
# 546210                         0                        0
# 546211                         0                        0
#
#         ESTU_DEPTO_RESIDE_VAUPES  ESTU_DEPTO_RESIDE_VICHADA  ESTU_GENERO_M
# 0                              0                          0              1
# 1                              0                          0              1
# 2                              0                          0              1
# 4                              0                          0              1
# 7                              0                          0              1
# ...                          ...                        ...            ...
# 546207                         0                          0              1
# 546208                         0                          0              1
# 546209                         0                          0              1
# 546210                         0                          0              1
# 546211                         0                          0              1
#
# [347677 rows x 59 columns]

# %%
cols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-530388441d18> in <cell line: 1>()
# ----> 1 cols
#
# NameError: name 'cols' is not defined

# %%
cols = df_encoded.columns.tolist()
target_cols = list(filter(lambda x: 'PUNT' in x, cols )) # Columnas TARGET
input_cols = list(set(cols).difference(set(target_cols)))
estu_cols = list(filter(lambda x: 'ESTU' in x, input_cols ))
fami_cols = list(filter(lambda x: 'FAMI' in x, input_cols ))
resid_cols = list(filter(lambda x: 'ESTU_DEPTO_RESIDE' in x, input_cols ))
estu_sin_resi_cols = list(set(estu_cols).difference(set(resid_cols)))

# %%
len(fami_cols)

# %% [markdown]
# # Analisis avanzado

# %%
for i in fami_cols+estu_sin_resi_cols:
    sns.displot(data=df_encoded, x=i)
